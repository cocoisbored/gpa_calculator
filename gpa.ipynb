# %% [markdown]
# 単位数とGPAを読み込んで必要に応じて計算をしてくれるプログラムを作りたい

# %% [markdown]
# ライブラリ読み込み

# %%
import pandas as pd #表形式のデータを扱うライブラリを読み込む(csvの方は1行ずつ読み込み操作する)
from typing import Dict, Tuple

# %% [markdown]
# 定義：GPAの文字と数字変換、csvファイルを読み込む

# %%
Default_grade: Dict[str,float] = {"S":4.0, "A":3.0, "B":2.0, "C":1.0, "D":0}

def read_csv(filepath: str, encoding: str = "UTF-8") -> pd.DataFrame：
